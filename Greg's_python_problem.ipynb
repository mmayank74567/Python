# %% [markdown]
# <a href="https://colab.research.google.com/github/mmayank74567/Python/blob/master/Greg's_python_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Submission to Greg's python problem.
# By - Mayank Mishra

# %%
A = ''
B = ''
C = ''
D = ''
E = ''

# %%
from random import choice
def get_month():
    months = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'] #12 months range
    v = choice(months)
    return v

# %%
match = 0
x = 0
for i in range(10):
  x = x+1
  A = get_month()
  B = get_month()
  C = get_month()
  D = get_month()
  E = get_month()

  if (A==B or A==C or A==D  or A==E  or B==C  or B==D  or B==E  or C==D  or C==E  or D==E):
    match = match+1
    print('Common birthday found at',x, 'iteration ',[A,B,C,D,E])
print('No of times a match was found',match)
# Out:
# Common birthday found at 1 iteration  ['feb', 'jun', 'nov', 'apr', 'jun']
# Common birthday found at 5 iteration  ['oct', 'oct', 'jul', 'aug', 'jan']
# Common birthday found at 6 iteration  ['feb', 'nov', 'dec', 'apr', 'apr']
# Common birthday found at 7 iteration  ['jul', 'feb', 'nov', 'sep', 'sep']
# Common birthday found at 8 iteration  ['jan', 'feb', 'dec', 'feb', 'feb']
# Common birthday found at 10 iteration  ['jan', 'may', 'may', 'dec', 'nov']
# No of times a match was found 6

# %%
match = 0
x = 0
for i in range(100):
  x = x+1
  A = get_month()
  B = get_month()
  C = get_month()
  D = get_month()
  E = get_month()

  if (A==B or A==C or A==D  or A==E  or B==C  or B==D  or B==E  or C==D  or C==E  or D==E):
    match = match+1
    print('Common birthday found at',x, 'iteration ',[A,B,C,D,E])
print('No of times a match was found',match)
# Out:
# Common birthday found at 2 iteration  ['mar', 'sep', 'sep', 'nov', 'sep']
# Common birthday found at 3 iteration  ['apr', 'jan', 'jan', 'sep', 'apr']
# Common birthday found at 7 iteration  ['feb', 'dec', 'aug', 'feb', 'jul']
# Common birthday found at 8 iteration  ['nov', 'may', 'sep', 'nov', 'dec']
# Common birthday found at 9 iteration  ['feb', 'jul', 'feb', 'may', 'apr']
# Common birthday found at 10 iteration  ['jul', 'jun', 'mar', 'may', 'mar']
# Common birthday found at 11 iteration  ['jun', 'oct', 'jan', 'aug', 'oct']
# Common birthday found at 12 iteration  ['mar', 'oct', 'jan', 'dec', 'jan']
# Common birthday found at 13 iteration  ['sep', 'aug', 'aug', 'mar', 'apr']
# Common birthday found at 15 iteration  ['apr', 'may', 'sep', 'dec', 'dec']
# Common birthday found at 16 iteration  ['sep', 'sep', 'apr', 'sep', 'sep']
# Common birthday found at 17 iteration  ['jan', 'oct', 'mar', 'jul', 'jul']
# Common birthday found at 18 iteration  ['mar', 'aug', 'dec', 'aug', 'mar']
# ...

# %%
match = 0
x = 0
for i in range(1000):
  x = x+1
  A = get_month()
  B = get_month()
  C = get_month()
  D = get_month()
  E = get_month()

  if (A==B or A==C or A==D  or A==E  or B==C  or B==D  or B==E  or C==D  or C==E  or D==E):
    match = match+1
    print('Common birthday found at',x, 'iteration ',[A,B,C,D,E])
print('No of times a match was found',match)
# Out:
# Common birthday found at 1 iteration  ['may', 'jun', 'jun', 'aug', 'oct']
# Common birthday found at 3 iteration  ['may', 'sep', 'dec', 'sep', 'jul']
# Common birthday found at 4 iteration  ['dec', 'oct', 'sep', 'oct', 'jul']
# Common birthday found at 7 iteration  ['feb', 'may', 'jun', 'apr', 'apr']
# Common birthday found at 8 iteration  ['jul', 'mar', 'feb', 'dec', 'mar']
# Common birthday found at 10 iteration  ['sep', 'mar', 'nov', 'mar', 'dec']
# Common birthday found at 11 iteration  ['aug', 'mar', 'mar', 'jan', 'jan']
# Common birthday found at 12 iteration  ['jul', 'apr', 'may', 'apr', 'apr']
# Common birthday found at 13 iteration  ['jun', 'dec', 'oct', 'mar', 'oct']
# Common birthday found at 14 iteration  ['aug', 'mar', 'mar', 'apr', 'apr']
# Common birthday found at 16 iteration  ['oct', 'aug', 'dec', 'dec', 'may']
# Common birthday found at 17 iteration  ['nov', 'nov', 'feb', 'apr', 'jun']
# Common birthday found at 18 iteration  ['feb', 'sep', 'feb', 'jul', 'jan']
# ...

# %%
match = 0
x = 0
for i in range(10000):
  x = x+1
  A = get_month()
  B = get_month()
  C = get_month()
  D = get_month()
  E = get_month()

  if (A==B or A==C or A==D  or A==E  or B==C  or B==D  or B==E  or C==D  or C==E  or D==E):
    match = match+1
    print('Common birthday found at',x, 'iteration ',[A,B,C,D,E])
print('No of times a match was found',match)
# Out:
# Streaming output truncated to the last 5000 lines.
# Common birthday found at 1989 iteration  ['aug', 'jun', 'dec', 'jun', 'aug']
# Common birthday found at 1990 iteration  ['jun', 'jan', 'nov', 'jan', 'sep']
# Common birthday found at 1993 iteration  ['feb', 'oct', 'mar', 'mar', 'may']
# Common birthday found at 1994 iteration  ['apr', 'dec', 'jan', 'jan', 'feb']
# Common birthday found at 1995 iteration  ['jul', 'nov', 'oct', 'oct', 'aug']
# Common birthday found at 1996 iteration  ['jun', 'mar', 'dec', 'nov', 'mar']
# Common birthday found at 1997 iteration  ['jul', 'sep', 'jul', 'jun', 'jul']
# Common birthday found at 1998 iteration  ['mar', 'mar', 'jul', 'sep', 'aug']
# Common birthday found at 1999 iteration  ['nov', 'jan', 'sep', 'sep', 'oct']
# Common birthday found at 2000 iteration  ['mar', 'mar', 'may', 'apr', 'nov']
# Common birthday found at 2002 iteration  ['jul', 'may', 'mar', 'feb', 'mar']
# ...

# %%
match = 0
x = 0
for i in range(100000):
  x = x+1
  A = get_month()
  B = get_month()
  C = get_month()
  D = get_month()
  E = get_month()

  if (A==B or A==C or A==D  or A==E  or B==C  or B==D  or B==E  or C==D  or C==E  or D==E):
    match = match+1
    print('Common birthday found at',x, 'iteration ',[A,B,C,D,E])
print('No of times a match was found',match)
# Out:
# Streaming output truncated to the last 5000 lines.
# Common birthday found at 91888 iteration  ['aug', 'may', 'oct', 'aug', 'aug']
# Common birthday found at 91889 iteration  ['mar', 'sep', 'jan', 'jan', 'oct']
# Common birthday found at 91893 iteration  ['sep', 'oct', 'aug', 'oct', 'nov']
# Common birthday found at 91895 iteration  ['sep', 'apr', 'sep', 'feb', 'nov']
# Common birthday found at 91898 iteration  ['may', 'apr', 'mar', 'may', 'jun']
# Common birthday found at 91899 iteration  ['jul', 'nov', 'mar', 'mar', 'sep']
# Common birthday found at 91900 iteration  ['mar', 'oct', 'dec', 'sep', 'dec']
# Common birthday found at 91901 iteration  ['aug', 'aug', 'apr', 'nov', 'jan']
# Common birthday found at 91902 iteration  ['nov', 'jul', 'may', 'mar', 'nov']
# Common birthday found at 91903 iteration  ['dec', 'mar', 'aug', 'dec', 'mar']
# Common birthday found at 91904 iteration  ['jul', 'jan', 'oct', 'aug', 'aug']
# ...
